# %% [markdown]
# <a href="https://colab.research.google.com/github/Mighty2Skiddie/McCulloh-and-Pitts-neuron-and-Perceptron-Model-Deep-learning-tor-e/blob/main/MP_neuron_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets

# %%
breast_cancer = sklearn.datasets.load_breast_cancer()

# %%
data = pd.DataFrame(breast_cancer.data, columns=breast_cancer.feature_names)

# %%
data['Class']=breast_cancer.target

# %%
data
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
X = data.drop('Class', axis=1)
Y = data['Class']

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
print(breast_cancer.target_names)
# Out:
# ['malignant' 'benign']

# %%
data['Class'].value_counts()
# Out:
# Class
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
data.groupby('Class').mean()
# Out:
#        mean radius  mean texture  mean perimeter   mean area  mean smoothness  \
# Class
# 0        17.462830     21.604906      115.365377  978.376415         0.102898
# 1        12.146524     17.914762       78.075406  462.790196         0.092478
#
#        mean compactness  mean concavity  mean concave points  mean symmetry  \
# Class
# 0              0.145188        0.160775             0.087990       0.192909
# 1              0.080085        0.046058             0.025717       0.174186
#
#        mean fractal dimension  ...  worst radius  worst texture  \
# Class                          ...
# 0                    0.062680  ...     21.134811      29.318208
# 1                    0.062867  ...     13.379801      23.515070
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# Class
# 0           141.370330  1422.286321          0.144845           0.374824
# 1            87.005938   558.899440          0.124959           0.182673
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
#help(train_test_split)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=42,stratify=Y)

# %%
X_test.shape
# Out:
# (57, 30)

# %%
X_train.shape
# Out:
# (512, 30)

# %%
y_train.shape
# Out:
# (512,)

# %%
y_test.shape
# Out:
# (57,)

# %%
print(Y.mean(), y_train.mean(), y_test.mean())
# Out:
# 0.6274165202108963 0.626953125 0.631578947368421

# %%
#binarization for MP model
plt.plot(X_train,'*')
plt.show()

# %%
#help(plt.plot)

# %%
print(X.mean(), X_train.mean(), X_test.mean())
# Out:
# mean radius                 14.127292
# mean texture                19.289649
# mean perimeter              91.969033
# mean area                  654.889104
# mean smoothness              0.096360
# mean compactness             0.104341
# mean concavity               0.088799
# mean concave points          0.048919
# mean symmetry                0.181162
# mean fractal dimension       0.062798
# radius error                 0.405172
# texture error                1.216853
# perimeter error              2.866059
# area error                  40.337079
# smoothness error             0.007041
# compactness error            0.025478
# concavity error              0.031894
# concave points error         0.011796
# symmetry error               0.020542
# fractal dimension error      0.003795
# worst radius                16.269190
# worst texture               25.677223
# worst perimeter            107.261213
# worst area                 880.583128
# worst smoothness             0.132369
# ...

# %%
ax = sns.scatterplot(data=X_train.T)
plt.xticks(rotation=90)
ax.legend_.remove()

# %%
data.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
print(X.mean(), X_train.mean(), X_test.mean())
# Out:
# mean radius                 14.127292
# mean texture                19.289649
# mean perimeter              91.969033
# mean area                  654.889104
# mean smoothness              0.096360
# mean compactness             0.104341
# mean concavity               0.088799
# mean concave points          0.048919
# mean symmetry                0.181162
# mean fractal dimension       0.062798
# radius error                 0.405172
# texture error                1.216853
# perimeter error              2.866059
# area error                  40.337079
# smoothness error             0.007041
# compactness error            0.025478
# concavity error              0.031894
# concave points error         0.011796
# symmetry error               0.020542
# fractal dimension error      0.003795
# worst radius                16.269190
# worst texture               25.677223
# worst perimeter            107.261213
# worst area                 880.583128
# worst smoothness             0.132369
# ...

# %%
X_binarized_train_1=X_train['mean area'].map(lambda x: 0 if x>654 else 1).astype(int)

# %%
X_binarized_train_1
# Out:
# 413    0
# 517    0
# 245    1
# 102    1
# 28     0
#       ..
# 509    0
# 230    0
# 354    1
# 103    1
# 248    1
# Name: mean area, Length: 512, dtype: int64

# %%
ax1=sns.scatterplot(data=X_binarized_train_1)

# %%
X_binarized_train=X_train.apply(pd.cut,bins=2,labels=[1,0]).astype(int)

# %%
X_binarized_train
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 413            1             1               1          1                1
# 517            0             1               0          1                0
# 245            1             1               1          1                0
# 102            1             1               1          1                1
# 28             1             0               1          1                0
# ..           ...           ...             ...        ...              ...
# 509            1             1               1          1                0
# 230            1             1               1          1                0
# 354            1             1               1          1                1
# 103            1             1               1          1                1
# 248            1             0               1          1                1
#
# ...

# %%
plt.plot(X_binarized_train.T,'*')
plt.xticks(np.arange(0,30),breast_cancer.feature_names,rotation=90)
plt.show()

# %%
X_binarized_test=X_test['mean area']

# %%
X_binarized_test=X_test.apply(lambda col:pd.cut(col,bins=2,labels=[1,0]))

# %%
plt.plot(X_binarized_test.T,'*')
plt.xticks(np.arange(0,30),breast_cancer.feature_names,rotation=90)
plt.show()

# %%
X_binarized_train
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 413            1             1               1          1                1
# 517            0             1               0          1                0
# 245            1             1               1          1                0
# 102            1             1               1          1                1
# 28             1             0               1          1                0
# ..           ...           ...             ...        ...              ...
# 509            1             1               1          1                0
# 230            1             1               1          1                0
# 354            1             1               1          1                1
# 103            1             1               1          1                1
# 248            1             0               1          1                1
#
# ...

# %%
X_binarized_train=X_binarized_train.values
X_binarized_test=X_binarized_test.values

# %%
from random import randint

# %%
for b in range(X_binarized_train.shape[1]+1):
  y_pred_train=[]
  accurate_rows=0

  for x,y in zip(X_binarized_train,y_train):
      y_pred=(np.sum(x)>=b)
      y_pred_train.append(y_pred)
      accurate_rows+=(y==y_pred)

  print(b,accurate_rows/X_binarized_train.shape[0])
# Out:
# 0 0.626953125
# 1 0.626953125
# 2 0.626953125
# 3 0.626953125
# 4 0.626953125
# 5 0.626953125
# 6 0.626953125
# 7 0.626953125
# 8 0.626953125
# 9 0.626953125
# 10 0.626953125
# 11 0.626953125
# 12 0.626953125
# 13 0.62890625
# 14 0.6328125
# 15 0.638671875
# 16 0.642578125
# 17 0.65234375
# 18 0.662109375
# 19 0.6640625
# 20 0.677734375
# 21 0.6953125
# 22 0.712890625
# 23 0.740234375
# 24 0.775390625
# 25 0.802734375
# 26 0.830078125
# 27 0.861328125
# 28 0.8515625
# 29 0.80859375
# 30 0.71875

# %%
#init b initialize b
#model function
#predict function
#fit & fittransform function

# %%
from sklearn.metrics import accuracy_score

# %%
class Mp_neuron:
  def _init_(self):
    self.b=None

  def model(self,x):
    return(np.sum(x)>=self.b)

  def predict(self,X):
    Y=[]
    for x in X:
      result=self.model(x)
      Y.append(result)
    return np.array(Y)

  def fit(self,X,Y):
    accuracy={}
    for b in range(X.shape[1]+1):
      self.b=b
      Y_pred=self.predict(X)
      accuracy[b]=accuracy_score(Y_pred,Y)

    best_b=max(accuracy,key=accuracy.get)
    self.b=best_b
    print('optimal value of b is',best_b)
    print('corresponding accuracy',accuracy[best_b])

# %%
mpneuron=Mp_neuron()
mpneuron.fit(X_binarized_train,y_train)
# Out:
# optimal value of b is 27
# corresponding accuracy 0.861328125
